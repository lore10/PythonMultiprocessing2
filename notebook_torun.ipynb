# %%
# %run -i 'cpu_usage_1.py'  #tarda 42 segundos
# Out:
# 42.18682063795859

# %%
# %run -i 'gpu_usage_1.py'
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/AleLore/JupyterProjects/PythonMultiprocessing2/gpu_usage_1.py in <module>()
#       3 from numba import vectorize
#       4
# ----> 5 @vectorize(['float32(float32, float32)'], target='cuda')
#       6 def pow(a, b):
#       7     return a ** b
#
# /Users/AleLore/anaconda/envs/py36/lib/python3.6/site-packages/numba/npyufunc/decorators.py in wrap(func)
#     116
#     117     def wrap(func):
# --> 118         vec = Vectorize(func, **kws)
#     119         for sig in ftylist:
#     120             vec.add(sig)
#
# /Users/AleLore/anaconda/envs/py36/lib/python3.6/site-packages/numba/npyufunc/decorators.py in __new__(cls, func, **kws)
#      35         identity = cls.get_identity(kws)
#      36         cache = cls.get_cache(kws)
# ---> 37         imp = cls.get_target_implementation(kws)
# ...

# %%
# %run -i 'numba1.py'
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/AleLore/JupyterProjects/PythonMultiprocessing2/numba1.py in <module>()
#       4 from numba import vectorize, cuda
#       5
# ----> 6 @vectorize(['float32(float32, float32)'], target='cuda')
#       7 def VectorAdd(a, b):
#       8     return a + b
#
# /Users/AleLore/anaconda/envs/py36/lib/python3.6/site-packages/numba/npyufunc/decorators.py in wrap(func)
#     116
#     117     def wrap(func):
# --> 118         vec = Vectorize(func, **kws)
#     119         for sig in ftylist:
#     120             vec.add(sig)
#
# /Users/AleLore/anaconda/envs/py36/lib/python3.6/site-packages/numba/npyufunc/decorators.py in __new__(cls, func, **kws)
#      35         identity = cls.get_identity(kws)
#      36         cache = cls.get_cache(kws)
# ---> 37         imp = cls.get_target_implementation(kws)
# ...

# %%
import math
from numba import vectorize, cuda
import numpy as np


#vectorized capability of numba
@vectorize(['float32(float32, float32, float32)',
            'float64(float64, float64, float64)'],
           target='cuda')
def cu_discriminant(a, b, c):
    return math.sqrt(b ** 2 - 4 * a * c)

N = 10000
dtype = np.float32

# prepare the input
A = np.array(np.random.sample(N), dtype=dtype)
B = np.array(np.random.sample(N) + 10, dtype=dtype)
C = np.array(np.random.sample(N), dtype=dtype)

D = cu_discriminant(A, B, C)

print(D)  # print result
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/AleLore/JupyterProjects/PythonMultiprocessing2/numba1.py in <module>()
#       5 @vectorize(['float32(float32, float32, float32)',
#       6             'float64(float64, float64, float64)'],
# ----> 7            target='cuda')
#       8 def cu_discriminant(a, b, c):
#       9     return math.sqrt(b ** 2 - 4 * a * c)
#
# /Users/AleLore/anaconda/envs/py36/lib/python3.6/site-packages/numba/npyufunc/decorators.py in wrap(func)
#     116
#     117     def wrap(func):
# --> 118         vec = Vectorize(func, **kws)
#     119         for sig in ftylist:
#     120             vec.add(sig)
#
# /Users/AleLore/anaconda/envs/py36/lib/python3.6/site-packages/numba/npyufunc/decorators.py in __new__(cls, func, **kws)
#      35         identity = cls.get_identity(kws)
#      36         cache = cls.get_cache(kws)
# ...

# %% [markdown]
# # Another example

# %%
import numpy as np
from timeit import default_timer as timer

def VectorAdd(a, b, c):
    for i in range(a.size):
        c[i] = a[i] + b[i]
        
N= 32000000 #number of elements per array

A= np.ones(N, dtype=np.float32)
B= np.ones(N, dtype=np.float32)
C= np.zeros(N, dtype=np.float32)

start = timer()
VectorAdd(A, B, C)
vectoradd_time=timer()-start

print('C[:5] = ' + str(C[:5]))
print('C[-5:] = ' + str(C[-5:]))

print('VectorAdd took %f seconds' % vectoradd_time)
# Out:
# C[:5] = [2. 2. 2. 2. 2.]
# C[-5:] = [2. 2. 2. 2. 2.]
# VectorAdd took 12.656420 seconds

# %%
import numpy as np
from timeit import default_timer as timer
from numba import vectorize

#decorator fuction starts with @: shows the behavior of fuction to be accelerated, takes 2 
#arrays of float32 elements and generates an array of float32
#by default the target creates a single thread CPU version, but we can use gpu as target to
#create a massive parallel processing with gpu version
@vectorize(["float32(float32,float32)"], target='cuda')  #target='gpu'
def VectorAdd(a, b):
        return(a+b)
        
N= 32000000 #number of elements per array

A= np.ones(N, dtype=np.float32)
B= np.ones(N, dtype=np.float32)
C= np.zeros(N, dtype=np.float32)

start = timer()
C= VectorAdd(A, B)
vectoradd_time=timer()-start

print('C[:5] = ' + str(C[:5]))
print('C[-5:] = ' + str(C[-5:]))

print('VectorAdd took %f seconds' % vectoradd_time)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/AleLore/JupyterProjects/PythonMultiprocessing2/gpu_usage_1.py in <module>()
#       7 #by default the target creates a single thread CPU version, but we can use gpu as target to
#       8 #create a massive parallel processing with gpu version
# ----> 9 @vectorize(["float32(float32,float32)"], target='cuda')
#      10 def VectorAdd(a, b):
#      11         return(a+b)
#
# /Users/AleLore/anaconda/envs/py36/lib/python3.6/site-packages/numba/npyufunc/decorators.py in wrap(func)
#     116
#     117     def wrap(func):
# --> 118         vec = Vectorize(func, **kws)
#     119         for sig in ftylist:
#     120             vec.add(sig)
#
# /Users/AleLore/anaconda/envs/py36/lib/python3.6/site-packages/numba/npyufunc/decorators.py in __new__(cls, func, **kws)
#      35         identity = cls.get_identity(kws)
# ...
